# %%
# Basic data handling and I/O
import numpy as np
import pandas as pd

# Data visualization
import seaborn as sns
import matplotlib.pyplot as plt

# Data preparation
from scipy.io import arff
from sklearn.preprocessing import StandardScaler

# Feature selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.decomposition import PCA

# Model evaluation and splitting
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# Suppress warnings for clean output (optional)
import warnings
warnings.filterwarnings('ignore')

# Set visual aesthetics for plots (optional)
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 8)

# %%
# Load ARFF files using scipy
from scipy.io import arff
import pandas as pd

# Load a specific ARFF file (replace with the correct filename as needed)
data_1year, meta_1year = arff.loadarff('/Users/poojithramagiri/Desktop/ML Challenges/polish+companies+bankruptcy+data/1year.arff')
df_1year = pd.DataFrame(data_1year)

# %%
df_1year
# Out:
#          Attr1    Attr2    Attr3    Attr4     Attr5     Attr6     Attr7  \
# 0     0.200550  0.37951  0.39641  2.04720   32.3510  0.388250  0.249760
# 1     0.209120  0.49988  0.47225  1.94470   14.7860  0.000000  0.258340
# 2     0.248660  0.69592  0.26713  1.55480   -1.1523  0.000000  0.309060
# 3     0.081483  0.30734  0.45879  2.49280   51.9520  0.149880  0.092704
# 4     0.187320  0.61323  0.22960  1.40630   -7.3128  0.187320  0.187320
# ...        ...      ...      ...      ...       ...       ...       ...
# 7022  0.018371  0.47410 -0.13619  0.60839  -18.4490  0.018371  0.018371
# 7023 -0.013359  0.58354 -0.02265  0.92896  -42.2320 -0.013359 -0.015036
# 7024  0.006338  0.50276  0.43923  1.87360    9.7417  0.006338  0.012022
# 7025 -0.041643  0.84810 -0.12852  0.57485 -121.9200  0.000000 -0.036795
# 7026  0.014946  0.94648  0.03211  1.03630  -20.5810  0.000000  0.015260
#
#          Attr8    Attr9    Attr10  ...    Attr56    Attr57   Attr58    Attr59  \
# ...

# %%
# Convert binary classification column to strings for clarity
df_1year['class'] = df_1year['class'].apply(lambda x: x.decode('utf-8'))

# %%
df_1year.head(5)
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5    Attr6     Attr7    Attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     Attr9   Attr10  ...    Attr56   Attr57   Attr58    Attr59  Attr60  Attr61  \
# 0  1.1389  0.50494  ...  0.121960  0.39718  0.87804  0.001924  8.4160  5.1372
# 1  1.6996  0.49788  ...  0.121300  0.42002  0.85300  0.000000  4.1486  3.2732
# 2  1.3090  0.30408  ...  0.241140  0.81774  0.76599  0.694840  4.9909  3.9510
# 3  1.0571  0.57353  ...  0.054015  0.14207  0.94598  0.000000  4.5746  3.6147
# 4  1.1559  0.38677  ...  0.134850  0.48431  0.86515  0.124440  6.3985  4.3158
#
#     Attr62  Attr63   Attr64  class
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.metrics import accuracy_score


# Handle missing values
imputer = SimpleImputer(strategy='median')
df_imputed = pd.DataFrame(imputer.fit_transform(df_1year), columns=df_1year.columns)

# Convert class variable to integer format
df_imputed['class'] = df_imputed['class'].astype(int)

# Separate features and target variable
X = df_imputed.drop('class', axis=1)
y = df_imputed['class']

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Initialize the base model
logistic = LogisticRegression(max_iter=1000)

# Initialize SequentialFeatureSelector for forward selection 
sfs = SequentialFeatureSelector(logistic, n_features_to_select=15, direction='forward')
sfs.fit(X_train, y_train)

# Transform the data to keep only selected features
X_train_selected = sfs.transform(X_train)
X_test_selected = sfs.transform(X_test)

# Fit the model using the selected features
logistic.fit(X_train_selected, y_train)
predictions = logistic.predict(X_test_selected)

# Evaluate the model
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy with selected features: {accuracy:.2f}")

# To see which features were selected
selected_features = [X.columns[i] for i in range(len(X.columns)) if sfs.get_support()[i]]
print("Selected features:", selected_features)
# Out:
# Accuracy with selected features: 0.96
# Selected features: ['Attr1', 'Attr4', 'Attr5', 'Attr7', 'Attr9', 'Attr10', 'Attr11', 'Attr13', 'Attr16', 'Attr19', 'Attr20', 'Attr21', 'Attr22', 'Attr23', 'Attr27']

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have logistic regression coefficients or you can use any metric of importance
feature_importances = np.abs(logistic.coef_[0])  # Taking absolute value of coefficients for visualization

# Creating a bar chart for feature importances
plt.figure(figsize=(10, 6))
indices = np.argsort(feature_importances)
plt.title('Feature Importances')
plt.barh(range(len(indices)), feature_importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [selected_features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SequentialFeatureSelector
from scipy.io import arff
import pandas as pd
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import numpy as np

data_2year, meta_2year = arff.loadarff('/Users/poojithramagiri/Desktop/ML Challenges/polish+companies+bankruptcy+data/2year.arff')
df_2year = pd.DataFrame(data_2year)

df_2year.head

# Handle missing values
imputer = SimpleImputer(strategy='median')
df2_imputed = pd.DataFrame(imputer.fit_transform(df_2year), columns=df_2year.columns)

# Convert class variable to integer format
df2_imputed['class'] = df2_imputed['class'].astype(int)

# Separate features and target variable
X = df2_imputed.drop('class', axis=1)
y = df2_imputed['class']

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Initialize the base model
logistic = LogisticRegression(max_iter=1000)

# Initialize variables for dynamic selection
desired_accuracy = 0.96
current_accuracy = 0
selected_features = []

# Loop to dynamically select features until the desired accuracy is achieved
for n_features in range(1, X_train.shape[1] + 1):
    sfs = SequentialFeatureSelector(logistic, n_features_to_select=n_features, direction='forward')
    sfs.fit(X_train, y_train)
    
    # Transform the data to keep only selected features
    X_train_selected = sfs.transform(X_train)
    X_test_selected = sfs.transform(X_test)
    
    # Fit the model using the selected features
    logistic.fit(X_train_selected, y_train)
    predictions = logistic.predict(X_test_selected)
    
    # Evaluate the model
    accuracy = accuracy_score(y_test, predictions)
    if accuracy >= desired_accuracy:
        current_accuracy = accuracy
        selected_features = [X.columns[i] for i in range(len(X.columns)) if sfs.get_support()[i]]
        break

print(f"Accuracy with selected features: {current_accuracy:.2f}")
print("Selected features:", selected_features)

# Visualization of feature importances
feature_importances = np.abs(logistic.coef_[0])
plt.figure(figsize=(10, 6))
indices = np.argsort(feature_importances)
plt.title('Feature Importances')
plt.barh(range(len(indices)), feature_importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [selected_features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()
# Out:
# Accuracy with selected features: 0.97
# Selected features: ['Attr1']
